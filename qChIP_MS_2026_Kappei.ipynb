# %% [markdown]
# <a href="https://colab.research.google.com/github/BDB-Genomics/qchip-ms-replication/blob/main/qChIP_MS_2026_Kappei.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #"qChIP-MS reveals the local chromatin composition by label-free quantitative proteomics" — Yong et al., Nature Communications, 2026 (DOI: 10.1038/s41467-026-73609-9)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
